# %%
import torch
print(f"PyTorch 版本: {torch.__version__}")
print(f"CUDA（GPU）是否可用: {torch.cuda.is_available()}")
# Out:
# PyTorch 版本: 2.10.0+cpu
# CUDA（GPU）是否可用: False

# %%
a = torch.tensor([232.3,231.7,231.8])
print(torch.mean(a))
print((2.32*500*279.8)/(1500*1.33*0.0001*231.9))
# Out:
# tensor(231.9333)
# 7015.555274559836

# %% [markdown]
# $\prod_
