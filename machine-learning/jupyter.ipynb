# %%
print('hello world')
# shift + enter 运行本代码块并跳转到下一个代码块
# ctrl + enter 运行本代码块
# Out:
# hello world

# %% [markdown]
# **光标在代码内时为编辑模式，否则为命令模式**
# **命令模式下，可直接复制，删除整个代码块，使用箭头直接切换选中的代码块**
# **esc 从编辑模式退回命令模式，空格 从命令模式进入编辑模式**

# %%
# 在命令模式下，M 为更改为markdown，Y 为更改为代码, B 为在下方创建新代码块，A 为在上方创建新代码块，X 剪切，C 复制
# shift + V 在当前代码块的上方粘贴，V 为在当前代码块的下方粘贴

# %%
# 粘贴测试

# %%
# 粘贴测试
